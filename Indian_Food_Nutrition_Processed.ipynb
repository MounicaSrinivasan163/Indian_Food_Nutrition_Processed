# %% [markdown]
# <a href="https://colab.research.google.com/github/MounicaSrinivasan163/Indian_Food_Nutrition_Processed/blob/main/Indian_Food_Nutrition_Processed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Indian_Food_Nutrition_Processed

# %% [markdown]
# # Data Reading

# %%
import pandas as pd
df = pd.read_csv('/content/Indian_Food_Nutrition_Processed.csv')
df.head()
# Out:
#                      Dish Name  Calories (kcal)  Carbohydrates (g)  \
# 0         Hot tea (Garam Chai)            16.14               2.58
# 1               Instant coffee            23.16               3.65
# 2               Espreso coffee            51.54               6.62
# 3                     Iced tea            10.34               2.70
# 4  Raw mango drink (Aam panna)            35.92               9.05
#
#    Protein (g)  Fats (g)  Free Sugar (g)  Fibre (g)  Sodium (mg)  \
# 0         0.39      0.53            2.58       0.00         3.12
# 1         0.64      0.75            3.62       0.00         4.92
# 2         1.75      2.14            6.53       0.00        13.98
# 3         0.03      0.01            2.70       0.00         0.23
# 4         0.16      0.03            7.49       0.61        79.82
#
#    Calcium (mg)  Iron (mg)  Vitamin C (mg)  Folate (µg)
# 0         14.20       0.02            0.50         1.80
# 1         20.87       0.06            1.51         5.60
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dish Name          1014 non-null   object
#  1   Calories (kcal)    1014 non-null   float64
#  2   Carbohydrates (g)  1014 non-null   float64
#  3   Protein (g)        1014 non-null   float64
#  4   Fats (g)           1014 non-null   float64
#  5   Free Sugar (g)     1014 non-null   float64
#  6   Fibre (g)          1014 non-null   float64
#  7   Sodium (mg)        1014 non-null   float64
#  8   Calcium (mg)       1014 non-null   float64
#  9   Iron (mg)          1014 non-null   float64
#  10  Vitamin C (mg)     932 non-null    float64
#  11  Folate (µg)        932 non-null    float64
# dtypes: float64(11), object(1)
# memory usage: 95.2+ KB

# %% [markdown]
# # Data Preprocessing/cleaning

# %%
df.isnull().sum()
# Out:
# Dish Name             0
# Calories (kcal)       0
# Carbohydrates (g)     0
# Protein (g)           0
# Fats (g)              0
# Free Sugar (g)        0
# Fibre (g)             0
# Sodium (mg)           0
# Calcium (mg)          0
# Iron (mg)             0
# Vitamin C (mg)       82
# Folate (µg)          82
# dtype: int64

# %%
df.describe()
# Out:
#        Calories (kcal)  Carbohydrates (g)  Protein (g)     Fats (g)  \
# count      1014.000000        1014.000000  1014.000000  1014.000000
# mean        233.735897          18.354004     4.753008    16.267584
# std         187.599467          16.745936     3.442746    20.452322
# min           6.610000           0.000000     0.000000     0.000000
# 25%         101.180000           5.582500     2.100000     4.030000
# 50%         174.920000          11.925000     3.990000     9.095000
# 75%         315.845000          26.870000     6.602500    17.085000
# max         839.330000          86.530000    21.550000    90.450000
#
#        Free Sugar (g)    Fibre (g)   Sodium (mg)  Calcium (mg)    Iron (mg)  \
# count     1014.000000  1014.000000   1014.000000   1014.000000  1014.000000
# mean         8.824832     1.962485    481.076755     59.877091     1.136953
# std         12.378324     2.771622   1750.646423     67.441463     1.520863
# ...

# %%
df['Vitamin C (mg)']= df['Vitamin C (mg)'].fillna(df['Vitamin C (mg)'].median())
df['Folate (µg)']=df['Folate (µg)'].fillna(df['Folate (µg)'].median())
df.isna().sum()
# Out:
# Dish Name            0
# Calories (kcal)      0
# Carbohydrates (g)    0
# Protein (g)          0
# Fats (g)             0
# Free Sugar (g)       0
# Fibre (g)            0
# Sodium (mg)          0
# Calcium (mg)         0
# Iron (mg)            0
# Vitamin C (mg)       0
# Folate (µg)          0
# dtype: int64

# %%
df.duplicated().sum() #no duplicates found
# Out:
# np.int64(0)

# %% [markdown]
# # Pandas Analysis

# %%
#Find the top 10 food items with the highest protein content.

df.sort_values(by='Protein (g)',ascending=False).head(10)
# Out:
#                                               Dish Name  Calories (kcal)  \
# 683                                  Gun powder chutney           312.34
# 539                                       Roast chicken           199.90
# 849                                       Lemon chicken           169.79
# 930                                   Maa chaane ki dal           344.67
# 1013                Bengal 5 Spice Blend (Panch Phoran)           289.79
# 850                                   Lemon butter fish           160.25
# 222                                    Tandoori chicken           145.20
# 551                                  Baked stuffed fish           121.96
# 232                                          Fish tikka           117.33
# 956   Cracked wheat and green gram dal premix (Dalia...           362.16
#
#       Carbohydrates (g)  Protein (g)  Fats (g)  Free Sugar (g)  Fibre (g)  \
# 683               47.65        21.55      2.67            1.16      13.95
# ...

# %%
#Find the average calories per dish.

df['Calories (kcal)'].mean()
# Out:
# np.float64(233.73589743589744)

# %%
#Which dish has the highest calcium content?

df[df['Calcium (mg)']==df['Calcium (mg)'].max()]
# Out:
#                        Dish Name  Calories (kcal)  Carbohydrates (g)  \
# 319  Sesame ladoo (Til ke ladoo)           396.96               43.5
#
#      Protein (g)  Fats (g)  Free Sugar (g)  Fibre (g)  Sodium (mg)  \
# 319         10.7     19.64           38.63       7.72        18.55
#
#      Calcium (mg)  Iron (mg)  Vitamin C (mg)  Folate (µg)
# 319        631.82       8.94             0.0        18.17

# %%
#Count how many dishes have more than 20g of carbohydrates.

df[df['Carbohydrates (g)']>20].shape[0]
# Out:
# 349

# %%
#What is the average sodium content across all dishes?

df['Sodium (mg)'].mean()
# Out:
# np.float64(481.07675542406315)

# %%
#Group the dishes by high (>10g) vs low (≤10g) fat content and calculate the average protein.

df.groupby(df['Fats (g)']>10)['Protein (g)'].mean()
# Out:
# Fats (g)
# False    4.133805
# True     5.469702
# Name: Protein (g), dtype: float64

# %%
#Find dishes with both low sugar (<5g) and high fibre (>5g).

df[(df['Fibre (g)']>5)&(df['Free Sugar (g)']<5)]
# Out:
#                                               Dish Name  Calories (kcal)  \
# 85                                         Chapati/Roti           202.31
# 86                               Plain parantha/paratha           298.30
# 90                                 Dal parantha/paratha           268.24
# 92     Pea parantha/paratha (Matar ka parantha/paratha)           190.73
# 101                           Tandoori parantha/paratha           295.37
# 135                                       Makki ki roti           263.97
# 146   Black channa curry/Bengal gram curry (Kale cha...           140.68
# 149                                      Soyabean curry           163.28
# 150                    Kidney bean curry (Rajmah curry)           143.73
# 153                                       Khatta channa           202.57
# 162   Beans with coconut (Nariyal aur sem/phali; Bea...           131.63
# 163   Cauliflower with coconut (Nariyal ke saath pho...           132.11
# ...

# %%
#Calculate the correlation between calories and fats.
df['Calories (kcal)'].corr(df['Fats (g)'])
# Out:
# np.float64(0.9217115887269188)

# %%
#Identify dishes that are high in iron (>10mg) and vitamin C (>20mg).

df[(df['Iron (mg)']>10)&(df['Vitamin C (mg)']>20)]
# Out:
# Empty DataFrame
# Columns: [Dish Name, Calories (kcal), Carbohydrates (g), Protein (g), Fats (g), Free Sugar (g), Fibre (g), Sodium (mg), Calcium (mg), Iron (mg), Vitamin C (mg), Folate (µg)]
# Index: []

# %%
#Create a new column calorie_density = Calories / (Protein + Carbohydrates + Fats) and sort the top 5 dishes.

df['calorie_density'] = df['Calories (kcal)'] / (df['Protein (g)'] + df['Carbohydrates (g)'] + df['Fats (g)'])
df.sort_values(by='calorie_density',ascending=False).head()
# Out:
#                                             Dish Name  Calories (kcal)  \
# 943                                        Mayonnaise           774.86
# 602                                   French dressing           733.77
# 187                           Ghiya/Lauki Kofta Curry           638.71
# 185  Cauliflower kofta curry (Phoolgobhi kofta curry)           641.10
# 196                                          Dum aloo           682.33
#
#      Carbohydrates (g)  Protein (g)  Fats (g)  Free Sugar (g)  Fibre (g)  \
# 943               1.65         1.86     84.52            1.44       0.11
# 602               3.68         0.32     79.65            3.01       0.22
# 187               2.71         0.89     69.40            0.82       0.83
# 185               2.62         1.04     69.62            0.83       1.00
# 196               3.33         0.70     74.01            0.71       0.68
#
#      Sodium (mg)  Calcium (mg)  Iron (mg)  Vitamin C (mg)  Folate (µg)  \
# ...

# %%
df.drop(['calorie_density'],axis=1,inplace=True)

# %%
#Create a custom “Health Score” using a weighted formula:
#score = 0.4*Fibre + 0.3*Protein - 0.2*Free Sugar - 0.1*Sodium and rank dishes.

df['Health Score'] = 0.4*df['Fibre (g)'] + 0.3*df['Protein (g)'] - 0.2*df['Free Sugar (g)'] - 0.1*df['Sodium (mg)']
#rank the dishes based on health score
df_ranked = df.sort_values(by='Health Score', ascending=False)
df_ranked
# Out:
#                                               Dish Name  Calories (kcal)  \
# 993                       Sambar powder (Sambar masala)           297.46
# 992                         Rasam powder (Rasam masala)           267.96
# 989                                        Garam masala           254.21
# 956   Cracked wheat and green gram dal premix (Dalia...           362.16
# 1013                Bengal 5 Spice Blend (Panch Phoran)           289.79
# ...                                                 ...              ...
# 78                                        Egg drop soup            26.64
# 466                              Consomme au vermicelli            29.94
# 464                         Meat consomme (with mutton)            29.76
# 470                                         Cheese soup            41.13
# 939                                         Brown sauce           109.18
#
#       Carbohydrates (g)  Protein (g)  Fats (g)  Free Sugar (g)  Fibre (g)  \
# ...

# %%
#Group dishes by calorie range (e.g., <200, 200–400, >400) and compute average values of all other nutrients.

df['Calories (kcal)'].describe()

# Define calorie bins and labels
bins = [0, 200, 400, float('inf')]
labels = ['<200 kcal', '200–400 kcal', '>400 kcal']

# Create a new column for calorie range
df['Calorie Range'] = pd.cut(df['Calories (kcal)'], bins=bins, labels=labels, include_lowest=True)

# Group by calorie range and compute mean of all nutrients (excluding Dish Name)
avg_nutrients_by_cal_range = df.groupby('Calorie Range').mean(numeric_only=True)

avg_nutrients_by_cal_range
# Out:
# /tmp/ipython-input-43-2211175990.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_nutrients_by_cal_range = df.groupby('Calorie Range').mean(numeric_only=True)
#                Calories (kcal)  Carbohydrates (g)  Protein (g)   Fats (g)  \
# Calorie Range
# <200 kcal           109.954441          11.852017     4.391695   5.780949
# 200–400 kcal        282.253551          32.760204     6.437878  14.245020
# >400 kcal           575.323799          20.067151     3.637821  53.600782
#
#                Free Sugar (g)  Fibre (g)  Sodium (mg)  Calcium (mg)  \
# Calorie Range
# <200 kcal            6.470203   1.610763   678.944458     56.636203
# 200–400 kcal        14.332531   3.059265   255.423306     84.562490
# >400 kcal            9.047430   1.620615   137.742402     36.772067
#
# ...

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Dish Name'] = le.fit_transform(df['Dish Name'])
df.head()
# Out:
#    Dish Name  Calories (kcal)  Carbohydrates (g)  Protein (g)  Fats (g)  \
# 0        419            16.14               2.58         0.39      0.53
# 1        426            23.16               3.65         0.64      0.75
# 2        316            51.54               6.62         1.75      2.14
# 3        422            10.34               2.70         0.03      0.01
# 4        762            35.92               9.05         0.16      0.03
#
#    Free Sugar (g)  Fibre (g)  Sodium (mg)  Calcium (mg)  Iron (mg)  \
# 0            2.58       0.00         3.12         14.20       0.02
# 1            3.62       0.00         4.92         20.87       0.06
# 2            6.53       0.00        13.98         58.10       0.15
# 3            2.70       0.00         0.23          1.18       0.02
# 4            7.49       0.61        79.82          7.08       0.14
#
#    Vitamin C (mg)  Folate (µg)
# 0            0.50         1.80
# 1            1.51         5.60
# 2            1.51         5.53
# ...

# %% [markdown]
# # Correlation Analysis

# %%
df.corr()
# Out:
#                    Dish Name  Calories (kcal)  Carbohydrates (g)  Protein (g)  \
# Dish Name           1.000000         0.017267          -0.011271    -0.135503
# Calories (kcal)     0.017267         1.000000           0.225926    -0.018079
# Carbohydrates (g)  -0.011271         0.225926           1.000000     0.136422
# Protein (g)        -0.135503        -0.018079           0.136422     1.000000
# Fats (g)            0.018757         0.921712          -0.152554    -0.109697
# Free Sugar (g)     -0.048716         0.090673           0.765213    -0.094466
# Fibre (g)           0.048260         0.034743           0.203843     0.280093
# Sodium (mg)        -0.093920        -0.168387          -0.155183     0.296879
# Calcium (mg)       -0.078492        -0.077906           0.055052     0.407861
# Iron (mg)          -0.004967         0.032676           0.205253     0.401453
# Vitamin C (mg)      0.033837        -0.191384          -0.268849    -0.111467
# ...

# %% [markdown]
# # Statistical Analysis

# %%
continuous = ['Dish Name']
categories = ['Calories (kcal)', 'Carbohydrates (g)', 'Protein (g)',
       'Fats (g)', 'Free Sugar (g)', 'Fibre (g)', 'Sodium (mg)',
       'Calcium (mg)', 'Iron (mg)', 'Vitamin C (mg)', 'Folate (µg)']

# %%
from scipy import stats

# %%
#TWO SAMPLE T - TEST : continuous vs continuous
def two_sample(d1,d2):
  t=0
  f=0
  for i in  range(31):
    sample1=d1.sample(frac=0.03)
    sample2=d2.sample(frac=0.03)
    t_test,p_value=stats.ttest_ind(sample1,sample2)
    if p_value < 0.05:
      f=f+1
    else:
      t=t+1
  if t>f:
    return True
  else:
    return False

# %%
#CHI-SQUARE TEST - category vs category
def chisquare_cat_vs_cat(d1,d2):
    return True if stats.chi2_contingency(pd.crosstab(d1,d2))[1] < 0.05 else False

# %%
#ANNOVA TEST - continious vs category
def annova_test(d1,d2):
    group= df[d2].unique()
    data = {}
    for i in group:
        data[i]=df[d1][df[d2]==i]
    f_value,p_value=stats.f_oneway(*[i for i in data.values()])
    return False if p_value < 0.05 else True

# %%
#All the statistical test being done across all the columns
final = {}
for i in df.columns:
    final[i]={}
    for j in df.columns:
        if (i in continuous) and (j in continuous):
            result=two_sample(df[i],df[j])
        elif (i in continuous) and (j in categories):
            result=annova_test(i,j)
        elif (i in categories) and (j in continuous):
            result=annova_test(j,i)
        elif (i in categories) and (j in categories):
            result=chisquare_cat_vs_cat(df[i],df[j])
        if result:
            final[i][j]=1
        else:
            final[i][j]=0

# %%
#The result of the statistical test which was in a dictionary is put into a dataframe
final_df = pd.DataFrame(final)
final_df
# Out:
#                    Dish Name  Calories (kcal)  Carbohydrates (g)  Protein (g)  \
# Dish Name                  1                1                  1            1
# Calories (kcal)            1                1                  1            1
# Carbohydrates (g)          1                1                  1            1
# Protein (g)                1                1                  1            1
# Fats (g)                   1                1                  0            1
# Free Sugar (g)             1                1                  1            0
# Fibre (g)                  1                1                  1            1
# Sodium (mg)                1                1                  1            1
# Calcium (mg)               1                1                  1            1
# Iron (mg)                  1                1                  1            1
# Vitamin C (mg)             1                1                  0            0
# ...

# %%
import seaborn as sns
#heatmap analysis for better visualisation of the stastical test results
sns.heatmap(final_df,annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
#INFERENCES:
#Though some columns showed minimal correlation, through statistical test we found it shows  significance.
# Thus we are going ahead without droping any columns
